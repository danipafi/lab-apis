# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "4058542463714ff1b0d7596b311b8ea3"
CLIENT_SECRET = "5b81532799614ef9a7bccf2a5337f8bb"

# %%
# CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
# CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 893

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
track = results['tracks']['items'][0] 
artist_id = track['artists'][0]['id']
artist_id
# Out:
# '1HY2Jd0NmPuamShAr6KMms'

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '5DQIZ8XC0EP7cfRFrtzY5h'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Happy Mistake'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 74

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5DQIZ8XC0EP7cfRFrtzY5h'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
artists = ["Beyoncé", "Sza", "Feid"]

def get_top_tracks(artists):
    top_tracks_list = []
    for artist in artists:
        result = sp.search(q=artist, limit=50)
        
        for i in range(5):
            track = result["tracks"]["items"][i]["name"]
            top_tracks_list.append(track)
            
    return top_tracks_list

# %%
top_tracks = get_top_tracks(artists)
print(top_tracks)
# Out:
# ['HEATED', 'ALIEN SUPERSTAR', 'CUFF IT', 'Dangerously In Love', 'Formation', 'Snooze', 'Saturn', 'Nobody Gets Me', 'Ghost in the Machine (feat. Phoebe Bridgers)', 'F2F', 'SORRY 4 THAT MUCH', 'El Cielo', 'Brickell', 'SE ME OLVIDA', 'LUNA']

# %%
def find_related_artists(artists):
            
    related_artists_set = set()
    
    for artist in artists:
        results = sp.search(q=artist, limit=1)
        
        track = results['tracks']['items'][0] 
        artist_id = track['artists'][0]['id']
            
        related_artists = sp.artist_related_artists(artist_id)
                
        for n in range(5):
            artist_name = related_artists['artists'][n]['name']
            related_artists_set.add(artist_name)
    

    return list(related_artists_set)

# %%
related_artists_2 = find_related_artists(artists)

# %%
related_artists_2
# Out:
# ["Destiny's Child",
#  'Myke Towers',
#  'Nicki Minaj',
#  'Brray',
#  'Daniel Caesar',
#  'Sky Rompiendo',
#  'Summer Walker',
#  'Rauw Alejandro',
#  'The Pussycat Dolls',
#  'Ovy On The Drums',
#  'Miguel',
#  'Justin Timberlake',
#  'Paperboy Fabe',
#  'Brent Faiyaz',
#  'Rihanna']

# %%
related_artists_top_tracks = get_top_tracks(related_artists_2)

# %%
related_artists_top_tracks
# Out:
# ['Say My Name',
#  'Survivor',
#  "Jumpin', Jumpin'",
#  'Independent Women, Pt. 1',
#  'Bills, Bills, Bills',
#  'Girl',
#  'LALA',
#  'ADIVINO',
#  'LA FALDA',
#  'Llegará',
#  'Super Bass',
#  'Starships',
#  'Super Freaky Girl',
#  'FTCU',
#  'Barbie World (with Aqua) [From Barbie The Album]',
#  'Te Colaboro',
#  'LOKERA',
#  'LOKERA',
#  'Corazón Roto pt. 3',
#  'Corazón Roto - Remix',
#  'Get You (feat. Kali Uchis)',
#  'Best Part (feat. H.E.R.)',
#  'Loose',
#  'Superpowers',
#  'Japanese Denim',
#  'El Cielo',
#  'Sky High',
#  'Espectacular',
#  'El Plan',
#  "Ponte Pa' Mi",
#  'Girls Need Love',
#  'Hell N Back (feat. Summer Walker)',
#  'Playing Games (with Bryson Tiller) - Extended Version',
#  'Body',
#  'Deep',
#  'DILUVIO',
#  "Desenfocao'",
#  'Todo De Ti',
#  'Desesperados',
#  'Déjame Entrar',
#  'Buttons',
#  "Don't Cha",
#  'Top Of The World',
#  'Stickwitu',
#  'When I Grow Up',
#  'Mírame',
#  'On The Drums',
#  'Soltera - W Sound 01',
#  'QLONA',
# ...

# %%
"""
artist_ids = []

for artist in artists:
    results = sp.search(q=artist, limit=1)
        
    track = results['tracks']['items'][0] 
    artist_id = track['artists'][0]['id']
    artist_ids.append(artist_id)
        
artist_ids
"""
# Out:
# "\nartist_ids = []\n\nfor artist in artists:\n    results = sp.search(q=artist, limit=1)\n        \n    track = results['tracks']['items'][0] \n    artist_id = track['artists'][0]['id']\n    artist_ids.append(artist_id)\n        \nartist_ids\n"

# %%
"""
related_artists = sp.artist_related_artists('6vWDO969PvNqNYHIOW5v0m')
print(related_artists['artists'][0]['name'])

"""
# Out:
# "\nrelated_artists = sp.artist_related_artists('6vWDO969PvNqNYHIOW5v0m')\nprint(related_artists['artists'][0]['name'])\n\n"

# %%
# Adicione a importação necessária para OAuth
from spotipy.oauth2 import SpotifyOAuth

# Configure o redirect_uri (isso deve ser o mesmo que você registrou no painel do Spotify)
redirect_uri = "http://localhost:3000"  # Você pode usar esse URI para testes

# Autenticação usando OAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                               client_secret=CLIENT_SECRET,
                                               redirect_uri=redirect_uri,
                                               scope="playlist-modify-public"))

# Obter o ID do usuário autenticado
user_id = sp.current_user()['id']

# Criar uma nova playlist
playlist_name = "My new python playlist"  # Nome da playlist
playlist_description = "Top tracks de Beyoncé, Sza, Feid e artistas relacionados"  # Descrição da playlist
new_playlist = sp.user_playlist_create(user=user_id, name=playlist_name, public=True, description=playlist_description)

# Confirmar que a playlist foi criada com sucesso
print(f"Playlist '{new_playlist['name']}' criada com sucesso!")
# Out:
# Playlist 'My new python playlist' criada com sucesso!

# %%
new_playlist['id']
# Out:
# '2EjXNJCVbZSqcRtYqHdHOE'

# %%
track_ids = []

for track_name in related_artists_top_tracks:
    results = sp.search(q=track_name, type='track', limit=1)

    track_id = results['tracks']['items'][0]['id']  # Obter o ID da faixa
    track_ids.append(track_id)

# %%
sp.playlist_add_items('3oMXS8iPPbUttYnj3piZxF', track_ids, position=None)
# Out:
# {'snapshot_id': 'AAAAAuAykacEpFAfsXeBFTFgg9qQNORk'}

# %%
# Acessar dados da playlist
playlist_data = sp.playlist('3oMXS8iPPbUttYnj3piZxF')

for item in playlist_data['tracks']['items']:
    track = item['track']
    print(f"- {track['name']} by {', '.join(artist['name'] for artist in track['artists'])}")
# Out:
# - Say My Name by Destiny's Child
# - Survivor by Destiny's Child
# - Jumpin', Jumpin' by Destiny's Child
# - Independent Women, Pt. 1 - Pasadena Remix by Destiny's Child
# - Bills, Bills, Bills by Destiny's Child
# - Girls Just Wanna Have Some by Chromatics
# - LALA by Myke Towers
# - ADIVINO by Myke Towers, Bad Bunny
# - LA FALDA by Myke Towers
# - Llegará by Myke Towers
# - Super Bass by Nicki Minaj
# - Starships by Nicki Minaj
# - Super Freaky Girl by Nicki Minaj
# - FTCU by Nicki Minaj
# - Barbie World (with Aqua) [From Barbie The Album] by Nicki Minaj, Ice Spice, Aqua
# - Te Colaboro by Brray, Feid
# - LOKERA by Rauw Alejandro, Lyanno, Brray
# - LOKERA by Rauw Alejandro, Lyanno, Brray
# - Corazón Roto pt. 3 by Brray, Anuel AA, Chencho Corleone, JHAYCO, Ryan Castro
# - Corazón Roto - Remix by Brray, JHAYCO, Ryan Castro
# - Get You (feat. Kali Uchis) by Daniel Caesar, Kali Uchis
# - Best Part (feat. H.E.R.) by Daniel Caesar, H.E.R.
# - Loose by Daniel Caesar
# ...

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Henrique & Juliano e os maiores hits do país. O que tá bombando tá aqui.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0FOF1IUWK1W'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0FOF1IUWK1W',
#     'id': '37i9dQZF1DX0FOF1IUWK1W',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026a1ebc62d141888233619b19',
#       'width': None}],
#     'name': 'Top Brasil',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# Cold Heart - Acoustic
# If I Ain't Got You - Piano & Vocal Version
# I'm Not the Only One - Live from Spotify, London
# Can't Help Falling in Love
# Wicked Game - Recorded Live at St Canice Cathedral, Kilkenny
# Bizarre Love Triangle - 2014 Remaster
# Too Good At Goodbyes - Acoustic
# La Vie En Rose
# Time After Time
# Stay With Me - Live From Spotify Berlin
# No One - Acoustic
# Sunday Morning - Acoustic
# Stand By Me
# IDGAF - Acoustic
# Billie Jean
# Fix You - Live
# Wake Me Up - Acoustic
# September Song - Guitar Acoustic
# Dreams - Piano Version
# Let Her Go (Acoustic Version)
# Fast Car
# Days Like This
# True Colours
# Unchained Melody
# Blinding Lights
# Baby One More Time - Recorded at Spotify Studios New York City
# Better Together
# Price Tag - Acoustic Version
# Ain't Nobody (Loves Me Better) - Acoustic
# Another Love - Live from Spotify (SXSW)
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# City of Stars
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Elton John', 'Dua Lipa', 'Alicia Keys', 'Kacey Musgraves', 'James Vincent McMorrow', 'Frente!', 'Sam Smith', 'Daniela Andrade', 'Iron & Wine', 'Angus & Julia Stone', 'Maroon 5', 'Florence + The Machine', 'The Civil Wars', 'Aloe Blacc', 'JP Cooper', 'Lissie', 'Passenger', 'Black Pumas', 'Dermot Kennedy', 'Tom Odell', 'Lykke Li', 'Ouvindo', 'Ed Sheeran', 'Us The Duo', 'Jessie J', 'Jasmine Thompson', 'James Bay', 'Gavin James', 'James Arthur', 'Charlie Puth', 'Arlo Parks', 'Halloran & Kate', 'Lauv', 'The Lumineers', 'The Mayries', 'Julia Michaels', 'Sixpence None The Richer', 'Kygo', 'Conrad Sewell', 'John Legend', 'Joy Williams', 'Howie Day', 'Sia', 'The Wind and The Wave', 'Lily Allen', 'Calum Scott', 'Missy & Blonde', 'Julia Ross', 'Lotte Kestner', 'Aaron Krause', 'Liza Anne', 'Taken By Trees', 'SOAK', 'Freedom Fry', 'John Mayer', 'Matt Johnson', "Israel Kamakawiwo'ole", 'Niall Horan', 'Francesco Yates', 'Joanna Wang', 'Sarah Jarosz', 'James Blunt', 'Julia Sheer', '
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
keys = sp.featured_playlists().keys()
print(keys)
# Out:
# dict_keys(['message', 'playlists'])

# %%
featured_playlists = sp.featured_playlists()
featured_playlists['playlists']['items'][0]['name']
# Out:
# 'Top Brasil'

# %%
featured_playlists['playlists']['items'][0]['id']
# Out:
# '37i9dQZF1DX0FOF1IUWK1W'

# %%
featured_playlists
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Henrique & Juliano e os maiores hits do país. O que tá bombando tá aqui.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0FOF1IUWK1W'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0FOF1IUWK1W',
#     'id': '37i9dQZF1DX0FOF1IUWK1W',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026a1ebc62d141888233619b19',
#       'width': None}],
#     'name': 'Top Brasil',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %%
for n in range(5):
    playlist_name = featured_playlists['playlists']['items'][n]['name'] 
    playlist_id = featured_playlists['playlists']['items'][n]['id']
    print(playlist_name)
    print(playlist_id)
# Out:
# Top Brasil
# 37i9dQZF1DX0FOF1IUWK1W
# Esquenta Sertanejo
# 37i9dQZF1DXdSjVZQzv2tl
# Funk Hits
# 37i9dQZF1DWTkIwO2HDifB
# Pagodeira
# 37i9dQZF1DWVjNkaVEkL3X
# Sucessos Gospel
# 37i9dQZF1DX0OEZC3cbQmU

# %%
# Fetch and display its name, description, and total track count.

playlist_id = '37i9dQZF1DWTkIwO2HDifB'
playlist = sp.playlist(playlist_id)

print(playlist['name'])  
print(playlist['description'])  
print(playlist['tracks']['total'])
# Out:
# Funk Hits
# A Danada Me Ligando  e os funks mais 🔑 do Brasil. Foto: Mc Cebezinho, DJ Oreia, Mc Tuto, Mc Kako
# 50

# %%
# Extract and display the names of the first 10 tracks in the chosen playlist.

tracks = sp.playlist_tracks(playlist_id)

tracks_list = []
artists_list = []

count = 0
while count < 10:
    for track in tracks['items']:
        track_name = track['track']['name']
        print(f"track name: {track_name}")  # Print each track's name
        tracks_list.append(track_name)
        
        track_artists = track['track']['artists']
        artist_names = [artist['name'] for artist in track_artists]
        print(f"artists in this track: {artist_names}")
        artists_list.append(artist_names)
        
        count += 1
        
        if count >= 10:
            break
# Out:
# track name: A Danada Me Ligando
# artists in this track: ['MC Cebezinho', 'DJ Oreia', 'MC Tuto', 'Love Funk', 'Mc Kako']
# track name: MTG PASSA PASSA PRA EU SARRAR
# artists in this track: ['Mc Livinho', 'DJ TOPO']
# track name: Clack Bum
# artists in this track: ['Mc J Mito', 'Kaio Viana', 'DJ Borest']
# track name: Mó Fita
# artists in this track: ['Dj Victor', 'MC Tuto', 'MC LUUKY', 'Mc Kadu']
# track name: É Que Eu Te Sarrei
# artists in this track: ['DJ THG', 'Mc Arizinho', 'Tavin']
# track name: Do Jeito Que Você Mete
# artists in this track: ['DJ L30', 'MC Thaizinha']
# track name: THE BOX MEDLEY FUNK 2
# artists in this track: ['THE BOX', 'Mc Brinquedo', 'MC Cebezinho', 'MC Tuto', 'Mc Laranjinha', 'DJ Oreia']
# track name: Mtg Forró e Desmantelo
# artists in this track: ['dj sv', 'Doug Hits', 'Manim Vaqueiro']
# track name: 365 Dias
# artists in this track: ['Dj Victor', 'Mc Kadu', 'Mc Kanhoto', 'MC G10', 'Mc Lele JP', 'MC Vine7', 'MC Menor da VG']
# ...

# %%
tracks_list
# Out:
# ['A Danada Me Ligando',
#  'MTG PASSA PASSA PRA EU SARRAR',
#  'Clack Bum',
#  'Mó Fita',
#  'É Que Eu Te Sarrei',
#  'Do Jeito Que Você Mete',
#  'THE BOX MEDLEY FUNK 2',
#  'Mtg Forró e Desmantelo',
#  '365 Dias',
#  'Mtg Quero Te Encontrar']

# %%
artists_list
# Out:
# [['MC Cebezinho', 'DJ Oreia', 'MC Tuto', 'Love Funk', 'Mc Kako'],
#  ['Mc Livinho', 'DJ TOPO'],
#  ['Mc J Mito', 'Kaio Viana', 'DJ Borest'],
#  ['Dj Victor', 'MC Tuto', 'MC LUUKY', 'Mc Kadu'],
#  ['DJ THG', 'Mc Arizinho', 'Tavin'],
#  ['DJ L30', 'MC Thaizinha'],
#  ['THE BOX',
#   'Mc Brinquedo',
#   'MC Cebezinho',
#   'MC Tuto',
#   'Mc Laranjinha',
#   'DJ Oreia'],
#  ['dj sv', 'Doug Hits', 'Manim Vaqueiro'],
#  ['Dj Victor',
#   'Mc Kadu',
#   'Mc Kanhoto',
#   'MC G10',
#   'Mc Lele JP',
#   'MC Vine7',
#   'MC Menor da VG'],
#  ['DJ JZ',
#   'Humberto & Ronaldo',
#   'Mc Mininin',
#   'DJ LG PROD',
#   'Silvanno Salles']]

# %%
# Create a dictionary where the keys are the names of the first 10 tracks, and the 
# values are lists containing the names of the artists associated with each track.
# For example: {"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}


tracks_dict = dict(zip(tracks_list, artists_list))

print(tracks_dict)
# Out:
# {'A Danada Me Ligando': ['MC Cebezinho', 'DJ Oreia', 'MC Tuto', 'Love Funk', 'Mc Kako'], 'MTG PASSA PASSA PRA EU SARRAR': ['Mc Livinho', 'DJ TOPO'], 'Clack Bum': ['Mc J Mito', 'Kaio Viana', 'DJ Borest'], 'Mó Fita': ['Dj Victor', 'MC Tuto', 'MC LUUKY', 'Mc Kadu'], 'É Que Eu Te Sarrei': ['DJ THG', 'Mc Arizinho', 'Tavin'], 'Do Jeito Que Você Mete': ['DJ L30', 'MC Thaizinha'], 'THE BOX MEDLEY FUNK 2': ['THE BOX', 'Mc Brinquedo', 'MC Cebezinho', 'MC Tuto', 'Mc Laranjinha', 'DJ Oreia'], 'Mtg Forró e Desmantelo': ['dj sv', 'Doug Hits', 'Manim Vaqueiro'], '365 Dias': ['Dj Victor', 'Mc Kadu', 'Mc Kanhoto', 'MC G10', 'Mc Lele JP', 'MC Vine7', 'MC Menor da VG'], 'Mtg Quero Te Encontrar': ['DJ JZ', 'Humberto & Ronaldo', 'Mc Mininin', 'DJ LG PROD', 'Silvanno Salles']}
